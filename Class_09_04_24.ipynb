# %% [markdown]
# <a href="https://colab.research.google.com/github/BrishavDebnath/Python/blob/main/Class_09_04_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
l=["SAPID"  ," FName"," Lname",  "Subject","Teacher", "Marks"]

# %%
l1=["500124352","Akarsh","Shukla","Maths","Ashishi Puri","71"]
l2=["500127120","Brishav","Debnath","Python","Syed Sajid","25"]
l3=["500124732","Tapabrata","Bhattacharya","Physics","Sachin Pathak","66"]

# %%
df=pd.DataFrame(data=np.array([l1,l2,l3]),index=["1","2","3"],columns= l)
print(df)
# Out:
#        SAPID      FName         Lname  Subject        Teacher Marks
# 1  500124352     Akarsh        Shukla    Maths   Ashishi Puri    71
# 2  500127120    Brishav       Debnath   Python     Syed Sajid    25
# 3  500124732  Tapabrata  Bhattacharya  Physics  Sachin Pathak    66

# %%
df.head()           #df.head(1)
# Out:
#        SAPID      FName         Lname  Subject        Teacher Marks
# 1  500124352     Akarsh        Shukla    Maths   Ashishi Puri    19
# 2  500127120    Brishav       Debnath   Python     Syed Sajid    15
# 3  500124732  Tapabrata  Bhattacharya  Physics  Sachin Pathak    18
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('SAPID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby(' FName').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
import seaborn as sns
sns.histplot(df,x="Marks",hue="Teacher")
# Out:
# <Axes: xlabel='Marks', ylabel='Count'>
